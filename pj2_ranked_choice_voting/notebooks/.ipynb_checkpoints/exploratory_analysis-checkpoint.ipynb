# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('dataframe.csv')

# %%
#print(data.head())

# %%
print(data.columns)
# Out:
# Index(['Age Group', 'Married', 'Education Level', 'Household Income',
#        'Direction of US', 'Direction of RI', 'Excitement about vote',
#        'Confidence in RI Politicians’ Care',
#        'Confidence in Local Voting Officials’ Election Management',
#        'Confidence in Accuracy of National Votes Cast',
#        'Same-Day Voter Registration Support', 'Ranked Choice Voting Support',
#        '1', '11', '12', '14', '15', '3', '5', '6', '7', '8', '9', 'Ward NaN',
#        'Female', 'Male', 'Non-binary / Other', 'Prefer not to say',
#        'Gender Identity NaN', 'Atheist', 'Buddhism', 'Catholic', 'Hinduism',
#        'Islam', 'Judaism', 'Other',
#        'Protestant / Other Christian Denomination', 'Religion NaN', 'Democrat',
#        'Independent', 'Other third party', 'Republican', 'Political Party NaN',
#        'Donald Trump', 'Kamala Harris', 'Other.1', 'Voted-For NaN',
#        'American Indian or Alaska Native', 'Asian',
# ...

# %%
# Color palette for plots
colors = sns.color_palette('bright')

# %%
# Determine the amount of missing data on ranked choice voting support
arc_NaN = len(data) - data['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(arc_NaN)

# Determine the average value for support of ranked choice voting
avg_rcv_support = data['Ranked Choice Voting Support'].mean()
#print(avg_rcv_support)

# For each level of support for ranked choice voting, determine how many people feel that way
rcv_1 = (data['Ranked Choice Voting Support'] == 1).sum()
rcv_2 = (data['Ranked Choice Voting Support'] == 2).sum()
rcv_3 = (data['Ranked Choice Voting Support'] == 3).sum()
rcv_4 = (data['Ranked Choice Voting Support'] == 4).sum()
rcv_5 = (data['Ranked Choice Voting Support'] == 5).sum()

# Create a dictionary from ranked choice voting support levels to the number of people with that support level
mean_rcv_values_dict = {
    'Definitely Not': rcv_1, 
    'Probably Not': rcv_2,
    'Need More Information': rcv_3,
    'Probably': rcv_4,
    'Definitely': rcv_5
}

# Turn dictionary into a series to be graphed
rcv_support = pd.DataFrame(mean_rcv_values_dict, index=[0]).iloc[0]

# %%
# Display the amount of people for each level of support for ranked choice voting

sns.barplot(x = rcv_support.index, y = rcv_support.values, hue = mean_rcv_values.index, palette = new_colors, legend = False)
plt.xlabel('Ranked Choice Voting Support Levels')
plt.ylabel('Number of People per Support Level')
plt.title('Number of People for Different Levels of Ranked Choice Voting Support')
plt.xticks(rotation=45)
plt.show()

# %%
# Ranked choice voting support by all voters

all_ranked_choice = data['Ranked Choice Voting Support'].value_counts()
arc_percentage = (all_ranked_choice / all_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(arc_percentage)

# Generate pie chart

plt.pie(arc_percentage, labels= arc_percentage.index, colors = colors, autopct='%1.1f%%')
plt.title('Ranked Choice Voting Support')
plt.show()

# %%
# Ranked choice voting support by candidate voted for
    # Column Names: Kamala Harris, Donald Trump, Other.1

# Determine how many missing values there are for who people voted for
voted_for_NaN = int(data['Voted-For NaN'].sum())
#print(voted_for_NaN)

harris_voters = data[data['Kamala Harris'] == 1] # Isolate Harris voters
harris_ranked_choice = harris_voters['Ranked Choice Voting Support'].value_counts() # Count the incidences of each level of support
harris_NaN = len(harris_voters) - harris_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(harris_NaN)
hrc_percentage = (harris_ranked_choice / harris_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(hrc_percentage)

trump_voters = data[data['Donald Trump'] == 1] # Isolate Trump voters
trump_ranked_choice = trump_voters['Ranked Choice Voting Support'].value_counts() # Count the incidences of each level of support
trump_NaN = len(trump_voters) - trump_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(trump_NaN)
trc_percentage = (trump_ranked_choice / trump_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(trc_percentage)

other_voters = data[data['Other.1'] == 1] # Isolate Other voters
other_ranked_choice = other_voters['Ranked Choice Voting Support'].value_counts() # Count the incidences of each level of support
other_NaN = len(other_voters) - other_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(other_NaN)
orc_percentage = (other_ranked_choice / other_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(orc_percentage)

# %%
# Generate pie charts for who people voted for

# Harris voters pie chart:
plt.pie(hrc_percentage, labels= hrc_percentage.index, colors = colors, autopct='%1.1f%%') 
plt.title('Harris Voters Ranked Choice Voting Support')
plt.show()

# Trump voters pie chart:
plt.pie(trc_percentage, labels= trc_percentage.index, colors = colors, autopct='%1.1f%%') 
plt.title('Trump Voters Ranked Choice Voting Support')
plt.show()

# Other voters pie chart:
plt.pie(orc_percentage, labels= orc_percentage.index, colors = colors, autopct='%1.1f%%') 
plt.title('3rd Party Voters Ranked Choice Voting Support')
plt.show()

# %%
# Ranked choice voting support by age
    # Column Names: Age Group

# Determine how many missing values there are for age group
age_group_NaN = len(data) - data['Age Group'].count()
#print(age_group_NaN)

age1_voters = data[data['Age Group'] == 1] # Isolate age group 1 voters
age1_ranked_choice = age1_voters['Ranked Choice Voting Support'].value_counts() # Count the incidences of each level of support
age1_NaN = len(age1_voters) - age1_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(age1_NaN)
a1rc_percentage = (age1_ranked_choice / age1_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(a1rc_percentage)

age2_voters = data[data['Age Group'] == 2] # Isolate age group 2 voters
age2_ranked_choice = age2_voters['Ranked Choice Voting Support'].value_counts() # Count the incidences of each level of support
age2_NaN = len(age2_voters) - age2_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(age2_NaN)
a2rc_percentage = (age2_ranked_choice / age2_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(a2rc_percentage)

age3_voters = data[data['Age Group'] == 3] # Isolate age group 3 voters
age3_ranked_choice = age3_voters['Ranked Choice Voting Support'].value_counts() # Count the incidences of each level of support
age3_NaN = len(age3_voters) - age3_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(age3_NaN)
a3rc_percentage = (age3_ranked_choice / age3_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(a3rc_percentage)

age4_voters = data[data['Age Group'] == 4] # Isolate age group 4 voters
age4_ranked_choice = age4_voters['Ranked Choice Voting Support'].value_counts() # Count the incidences of each level of support
age4_NaN = len(age4_voters) - age4_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(age4_NaN)
a4rc_percentage = (age4_ranked_choice / age4_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(a4rc_percentage)

age5_voters = data[data['Age Group'] == 5] # Isolate age group 5 voters
age5_ranked_choice = age5_voters['Ranked Choice Voting Support'].value_counts() # Count the incidences of each level of support
age5_NaN = len(age5_voters) - age5_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(age5_NaN)
a5rc_percentage = (age5_ranked_choice / age5_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(a5rc_percentage)

age6_voters = data[data['Age Group'] == 6] # Isolate age group 6 voters
age6_ranked_choice = age6_voters['Ranked Choice Voting Support'].value_counts() # Count the incidences of each level of support
age6_NaN = len(age6_voters) - age6_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(age6_NaN)
a6rc_percentage = (age6_ranked_choice / age6_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(a6rc_percentage)

# %%
# Generate pie charts for voter age groups

# Age group 1 pie chart:
plt.pie(a1rc_percentage, labels= a1rc_percentage.index, colors = colors, autopct='%1.1f%%')  
plt.title('18-24 Voters Ranked Choice Voting Support')
plt.show()

# Age group 2 pie chart:
plt.pie(a2rc_percentage, labels= a2rc_percentage.index, colors = colors, autopct='%1.1f%%')  
plt.title('25-29 Voters Ranked Choice Voting Support')
plt.show()

# Age group 3 pie chart:
plt.pie(a3rc_percentage, labels= a3rc_percentage.index, colors = colors, autopct='%1.1f%%') 
plt.title('30-39 Voters Ranked Choice Voting Support')
plt.show()

# Age group 4 pie chart:
plt.pie(a4rc_percentage, labels= a4rc_percentage.index, colors = colors, autopct='%1.1f%%') 
plt.title('40-49 Voters Ranked Choice Voting Support')
plt.show()

# Age group 5 pie chart:
plt.pie(a5rc_percentage, labels= a5rc_percentage.index, colors = colors, autopct='%1.1f%%') 
plt.title('50-64 Voters Ranked Choice Voting Support')
plt.show()

# Age group 6 pie chart:
plt.pie(a6rc_percentage, labels= a6rc_percentage.index, colors = colors, autopct='%1.1f%%')  
plt.title('65+ Voters Ranked Choice Voting Support')
plt.show()

# %%
# Merge age related series of data into a data frame
arc_data = pd.DataFrame({'18-24': a1rc_percentage, 
                         '25-29': a2rc_percentage, 
                         '30-39': a3rc_percentage, 
                         '40-49': a4rc_percentage, 
                         '50-64': a5rc_percentage, 
                         '65+': a6rc_percentage})

#print(arc_data)

# Isolate the rows of the dataframe
    # Indicates percentages of each age group that have ranked choice voting support equal to (row index + 1)
arc_support1 = arc_data.iloc[0]
arc_support2 = arc_data.iloc[1]
arc_support3 = arc_data.iloc[2]
arc_support4 = arc_data.iloc[3]
arc_support5 = arc_data.iloc[4]

# Build bar charts showing each support level across age groups

bar_colors = sns.color_palette("dark", len(arc_data.columns))

# Level 1 support across age groups
sns.barplot(x = arc_support1.index, y = arc_support1.values, hue = arc_support1.index, palette = bar_colors, legend = False)
plt.xlabel('Age Groups')
plt.ylabel('% with Support Level 1')
plt.title('"Definitely Not" Percentage by Age Group')
plt.show()

# Level 2 support across age groups
sns.barplot(x = arc_support2.index, y = arc_support2.values, hue = arc_support2.index, palette = bar_colors, legend = False)
plt.xlabel('Age Groups')
plt.ylabel('% with Support Level 2')
plt.title('"Probably Not" Percentage by Age Group')
plt.show()

# Level 3 support across age groups
sns.barplot(x = arc_support3.index, y = arc_support3.values, hue = arc_support3.index, palette = bar_colors, legend = False)
plt.xlabel('Age Groups')
plt.ylabel('% with Support Level 3')
plt.title('"Need More Information" Percentage by Age Group')
plt.show()

# Level 4 support across age groups
sns.barplot(x = arc_support4.index, y = arc_support4.values, hue = arc_support4.index, palette = bar_colors, legend = False)
plt.xlabel('Age Groups')
plt.ylabel('% with Support Level 4')
plt.title('"Probably" Percentage by Age Group')
plt.show()

# Level 5 support across age groups
sns.barplot(x = arc_support5.index, y = arc_support5.values, hue = arc_support5.index, palette = bar_colors, legend = False)
plt.xlabel('Age Groups')
plt.ylabel('% with Support Level 5')
plt.title('"Definitely" Percentage by Age Group')
plt.show()

# %%
# Ranked choice voting support by education level
    # Column Names: Education Level

# Determine how many missing values there are for education level
education_level_NaN = len(data) - data['Education Level'].count()
#print(education_level_NaN)

education1_voters = data[data['Education Level'] == 1] # Isolate education level 1 voters
education1_ranked_choice = education1_voters['Ranked Choice Voting Support'].value_counts() # Count the incidences of each level of support
education1_NaN = len(education1_voters) - education1_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(education1_NaN)
e1rc_percentage = (education1_ranked_choice / education1_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(e1rc_percentage)

education2_voters = data[data['Education Level'] == 2] # Isolate education level 2 voters
education2_ranked_choice = education2_voters['Ranked Choice Voting Support'].value_counts() # Count the incidences of each level of support
education2_NaN = len(education2_voters) - education2_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(education2_NaN)
e2rc_percentage = (education2_ranked_choice / education2_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(e2rc_percentage)

education3_voters = data[data['Education Level'] == 3] # Isolate education level 3 voters
education3_ranked_choice = education3_voters['Ranked Choice Voting Support'].value_counts() # Count the incidences of each level of support
education3_NaN = len(education3_voters) - education3_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(education3_NaN)
e3rc_percentage = (education3_ranked_choice / education3_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(e3rc_percentage)

education4_voters = data[data['Education Level'] == 4] # Isolate education level 4 voters
education4_ranked_choice = education4_voters['Ranked Choice Voting Support'].value_counts() # Count the incidences of each level of support
education4_NaN = len(education4_voters) - education4_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(education4_NaN)
e4rc_percentage = (education4_ranked_choice / education4_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(e4rc_percentage)

education5_voters = data[data['Education Level'] == 5] # Isolate education level 5 voters
education5_ranked_choice = education5_voters['Ranked Choice Voting Support'].value_counts() # Count the incidences of each level of support
education5_NaN = len(education5_voters) - education5_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(education5_NaN)
e5rc_percentage = (education5_ranked_choice / education5_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(e5rc_percentage)

education6_voters = data[data['Education Level'] == 6] # Isolate education level 6 voters
education6_ranked_choice = education6_voters['Ranked Choice Voting Support'].value_counts() # Count the incidences of each level of support
education6_NaN = len(education6_voters) - education6_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(education6_NaN)
e6rc_percentage = (education6_ranked_choice / education6_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(e6rc_percentage)

education7_voters = data[data['Education Level'] == 7] # Isolate education level 7 voters
education7_ranked_choice = education7_voters['Ranked Choice Voting Support'].value_counts() # Count the incidences of each level of support
education7_NaN = len(education7_voters) - education7_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(education7_NaN)
e7rc_percentage = (education7_ranked_choice / education7_ranked_choice.sum()).sort_index() # Find percentage of incidences (ignoring missing data)
#print(e7rc_percentage)

# %%
# Generate pie charts for voter education levels

# Education level 1 pie chart:
plt.pie(e1rc_percentage, labels= e1rc_percentage.index, colors = colors, autopct='%1.1f%%')  
plt.title('Less Than High School Voters Ranked Choice Voting Support')
plt.show()

# Education level 2 pie chart:
plt.pie(e2rc_percentage, labels= e2rc_percentage.index, colors = colors, autopct='%1.1f%%')  
plt.title('High School Diploma/GED Voters Ranked Choice Voting Support')
plt.show()

# Education level 3 pie chart:
plt.pie(e3rc_percentage, labels= e3rc_percentage.index, colors = colors, autopct='%1.1f%%') 
plt.title('Some College Voters Ranked Choice Voting Support')
plt.show()

# Education level 4 pie chart:
plt.pie(e4rc_percentage, labels= e4rc_percentage.index, colors = colors, autopct='%1.1f%%') 
plt.title('2 Year Degree Voters Ranked Choice Voting Support')
plt.show()
    
# Education level 5 pie chart:
plt.pie(e5rc_percentage, labels= e5rc_percentage.index, colors = colors, autopct='%1.1f%%') 
plt.title('4 Year Degree Voters Ranked Choice Voting Support')
plt.show()

# Education level 6 pie chart:
plt.pie(e6rc_percentage, labels= e6rc_percentage.index, colors = colors, autopct='%1.1f%%')  
plt.title('Professional Degree Voters Ranked Choice Voting Support')
plt.show()

# Education level 7 pie chart:
plt.pie(e7rc_percentage, labels= e7rc_percentage.index, colors = colors, autopct='%1.1f%%')  
plt.title('Doctorate Voters Ranked Choice Voting Support')
plt.show()

# %%
# Mean ranked choice voting support by thoughts on direction of the country
    # Column Names: Direction of US

# Determine how many missing values there are for direction of US
US_direction_NaN = len(data) - data['Direction of US'].count()
#print(US_direction_NaN)

direction1_voters = data[data['Direction of US'] == 1] # Isolate "definitely wrong" direction voters
direction1_mean_rcv = direction1_voters['Ranked Choice Voting Support'].mean() # Calculate the mean level of rcv support
direction1_NaN = len(direction1_voters) - direction1_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(direction1_NaN)

direction2_voters = data[data['Direction of US'] == 2] # Isolate "somewhat wrong" direction voters
direction2_mean_rcv = direction2_voters['Ranked Choice Voting Support'].mean() # Calculate the mean level of rcv support
direction2_NaN = len(direction2_voters) - direction2_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(direction2_NaN)

direction3_voters = data[data['Direction of US'] == 3] # Isolate "unsure" direction voters
direction3_mean_rcv = direction3_voters['Ranked Choice Voting Support'].mean() # Calculate the mean level of rcv support
direction3_NaN = len(direction3_voters) - direction3_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(direction3_NaN)

direction4_voters = data[data['Direction of US'] == 4] # Isolate "somewhat right" direction voters
direction4_mean_rcv = direction4_voters['Ranked Choice Voting Support'].mean() # Calculate the mean level of rcv support
direction1_NaN = len(direction4_voters) - direction4_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(direction4_NaN)

direction5_voters = data[data['Direction of US'] == 5] # Isolate "definitely right" direction voters
direction5_mean_rcv = direction5_voters['Ranked Choice Voting Support'].mean() # Calculate the mean level of rcv support
direction5_NaN = len(direction5_voters) - direction5_voters['Ranked Choice Voting Support'].count() # Determine amount of missing data
#print(direction5_NaN)

# Gather mean values into a dictionary
mean_rcv_values_dict = {
    'Definitely Wrong': direction1_mean_rcv, 
    'Somewhat Wrong': direction2_mean_rcv,
    'Unsure': direction3_mean_rcv,
    'Somewhat Right': direction4_mean_rcv,
    'Definitely Right': direction4_mean_rcv
}

# Turn dictionary into a series to be graphed
mean_rcv_values = pd.DataFrame(mean_rcv_values_dict, index=[0]).iloc[0]

# %%
new_colors = sns.color_palette("dark", len(mean_rcv_values))

# Mean ranked choice voting support across opinions on direction of the US
sns.barplot(x = mean_rcv_values.values, y = mean_rcv_values.index, hue = mean_rcv_values.index, palette = new_colors, legend = False)
plt.xlabel('Mean Ranked Choice Voting Support')
plt.ylabel('Opinions on the Direction of the US')
plt.title('Mean Ranked Choice Voting Support Across Opinions on the Direction of the US')
plt.show()
