# %%
import pandas as pd

# File paths (adjust if necessary)
input_file = '/Users/yzc/Desktop/EVC project/RI-Voting-Models/raw_data/survey_data.csv'
output_file = '/Users/yzc/Desktop/EVC project/RI-Voting-Models/raw_data/survey_data_cleaned.csv'


# Load the CSV file
df = pd.read_csv(input_file)


df.head(5)
# Out:
#              StartDate              EndDate  Progress  Duration (in seconds)  \
# 0           Start Date             End Date  Progress  Duration (in seconds)
# 1  11/12/2024 18:19:16  11/12/2024 18:21:01       100                    104
# 2  11/12/2024 18:19:22  11/12/2024 18:21:06       100                    103
# 3  11/12/2024 18:19:26  11/12/2024 18:21:06       100                     99
# 4  11/12/2024 18:19:30  11/12/2024 18:21:13       100                    103
#
#    Finished         RecordedDate         ResponseId    RecipientLastName  \
# 0  Finished        Recorded Date        Response ID  Recipient Last Name
# 1      True  11/12/2024 18:21:02  R_7LvyIKEDwhcpXXd                  NaN
# 2      True  11/12/2024 18:21:06  R_3obsi8B2j0maSsH                  NaN
# 3      True  11/12/2024 18:21:06  R_7S003rcKqMsxg0i                  NaN
# 4      True  11/12/2024 18:21:14  R_6JRsucMt6YOLuvd                  NaN
#
#      RecipientFirstName   RecipientEmail  ...  \
# ...

# %%
# Keep only columns from 'Q1' onward
df = df.loc[:, 'Q1':]

# Drop the first row
df = df.iloc[1:].reset_index(drop=True)

# Fill missing values in all columns with "No Response"
df = df.fillna("No Response")

df.head(5)
# Out:
#    Q1     Q2      Q3           Q4  \
# 0   5  30-39  Female  Not married
# 1  15  30-39    Male  Not married
# 2   9  40-49    Male  Not married
# 3   1  18-24    Male  Not married
# 4   3  18-24  Female  Not married
#
#                                                   Q5  \
# 0  Black or African American,American Indian or A...
# 1                                        No Response
# 2                                              Asian
# 3                                              Asian
# 4                               Hispanic or Latino/a
#
#                                           Q6  Unnamed: 22  \
# 0  Protestant / Other Christian Denomination  No Response
# 1                                No Response  No Response
# 2                                No Response  No Response
# 3                                No Response  No Response
# 4                                No Response  No Response
#
# ...

# %%
df = df.drop('Unnamed: 22', axis=1)

df.head(5)
# Out:
#    Q1     Q2      Q3           Q4  \
# 0   5  30-39  Female  Not married
# 1  15  30-39    Male  Not married
# 2   9  40-49    Male  Not married
# 3   1  18-24    Male  Not married
# 4   3  18-24  Female  Not married
#
#                                                   Q5  \
# 0  Black or African American,American Indian or A...
# 1                                        No Response
# 2                                              Asian
# 3                                              Asian
# 4                               Hispanic or Latino/a
#
#                                           Q6                   Q7  \
# 0  Protestant / Other Christian Denomination        4 year degree
# 1                                No Response        4 year degree
# 2                                No Response  Professional degree
# 3                                No Response         Some college
# 4                                No Response         Some college
#
# ...

# %%
# Save the resulting DataFrame to a new CSV
df.to_csv(output_file, index=False)

# %%
rows, columns = df.shape
df.shape
print(f"Number of rows: {rows}")
print(f"Number of columns: {columns}")
print(df.dtypes)
print(df.describe())
# Out:
# Number of rows: 558
# Number of columns: 20
# Q1     object
# Q2     object
# Q3     object
# Q4     object
# Q5     object
# Q6     object
# Q7     object
# Q8     object
# Q9     object
# Q10    object
# Q11    object
# Q12    object
# Q13    object
# Q14    object
# Q15    object
# Q16    object
# Q17    object
# Q18    object
# Q19    object
# Q20    object
# dtype: object
#          Q1     Q2      Q3           Q4     Q5        Q6             Q7  \
# count   558    558     558          558    558       558            558
# unique   12      7       5            3     23         9              8
# top       8  30-39  Female  Not married  White  Catholic  4 year degree
# freq     86    141     318          350    223       155            135
#
#                       Q8        Q9             Q10             Q11  \
# count                558       558             558             558
# unique                 6         5               6               6
# ...

# %% [markdown]
# **Q1: Ward (One-Hot)**

# %%
### 1. Q1: Ward # (One-Hot)
# Allowed ward values as strings (to match CSV entries)
allowed_wards = ['1', '3', '5', '6', '7', '8', '9', '11', '12', '14', '15']
df['Q1'] = df['Q1'].astype(str)

# If the ward is not in the allowed list, assign "No Response"
df['Q1'] = df['Q1'].apply(lambda x: x if x in allowed_wards else "No Response")

# One-hot encode Q1
df = pd.concat([df, pd.get_dummies(df['Q1'], prefix='Q1')], axis=1)
# Out:
#    Q1     Q2      Q3           Q4  \
# 0   5  30-39  Female  Not married
# 1  15  30-39    Male  Not married
# 2   9  40-49    Male  Not married
# 3   1  18-24    Male  Not married
# 4   3  18-24  Female  Not married
#
#                                                   Q5  \
# 0  Black or African American,American Indian or A...
# 1                                        No Response
# 2                                              Asian
# 3                                              Asian
# 4                               Hispanic or Latino/a
#
#                                           Q6                   Q7  \
# 0  Protestant / Other Christian Denomination        4 year degree
# 1                                No Response        4 year degree
# 2                                No Response  Professional degree
# 3                                No Response         Some college
# 4                                No Response         Some college
#
# ...

# %%
df.head(5)

# %% [markdown]
# **Q2: Age (Ordinal)**

# %%
age_mapping = {
    "18-24": 1,
    "25-29": 2,
    "30-39": 3,
    "40-49": 4,
    "50-64": 5,
    "65+": 6,
    "No Response": 0  # Represent missing responses as 0
}
df['Q2'] = df['Q2'].map(age_mapping).fillna(0)
# Out:
# Q2
# 3.0    141
# 5.0    123
# 4.0     86
# 2.0     73
# 0.0     71
# 1.0     64
# Name: count, dtype: int64

# %%
print(df['Q2'].value_counts())

# %% [markdown]
# **Q3: Gender Identity (One-Hot)**

# %%
allowed_genders = ["Male", "Female", "Non-binary", "Prefer not to say"]
df['Q3'] = df['Q3'].astype(str)
df['Q3'] = df['Q3'].apply(lambda x: x if x in allowed_genders else "No Response")
df = pd.concat([df, pd.get_dummies(df['Q3'], prefix='Q3')], axis=1)

# %%
df.head(5)
# Out:
#    Q1   Q2      Q3           Q4  \
# 0   5  3.0  Female  Not married
# 1  15  3.0    Male  Not married
# 2   9  4.0    Male  Not married
# 3   1  1.0    Male  Not married
# 4   3  1.0  Female  Not married
#
#                                                   Q5  \
# 0  Black or African American,American Indian or A...
# 1                                        No Response
# 2                                              Asian
# 3                                              Asian
# 4                               Hispanic or Latino/a
#
#                                           Q6                   Q7  \
# 0  Protestant / Other Christian Denomination        4 year degree
# 1                                No Response        4 year degree
# 2                                No Response  Professional degree
# 3                                No Response         Some college
# 4                                No Response         Some college
#
# ...

# %% [markdown]
# **Q4: Marital Status (Binary)**

# %%
# Mapping: Married → 1, Not married → 0, and "No Response" as a separate category (-1)
def encode_marital(status):
    s = status.strip().lower()
    if s == "married":
        return 1
    elif s == "not married":
        return 0
    else:
        return -1  # Indicates no response or unexpected entry

df['Q4'] = df['Q4'].apply(encode_marital)

# %%
print(df['Q4'].value_counts())
# Out:
# Q4
#  0    350
#  1    201
# -1      7
# Name: count, dtype: int64

# %% [markdown]
# **Q5: Ethnicity (Multi-Hot)**

# %%
ethnicity_options = [
    "White",
    "Black or African American",
    "Hispanic or Latino/a",
    "Asian",
    "American Indian or Alaska Native",
    "Native Hawaiian or Pacific Islander",
    "Other"
]

# For each option, create a binary column if the option is present in the response string.
for option in ethnicity_options:
    df[f'Q5_{option}'] = df['Q5'].apply(lambda x: 1 if option in x else 0)

# %%
df.head(5)
# Out:
#    Q1   Q2      Q3  Q4                                                 Q5  \
# 0   5  3.0  Female   0  Black or African American,American Indian or A...
# 1  15  3.0    Male   0                                        No Response
# 2   9  4.0    Male   0                                              Asian
# 3   1  1.0    Male   0                                              Asian
# 4   3  1.0  Female   0                               Hispanic or Latino/a
#
#                                           Q6                   Q7  \
# 0  Protestant / Other Christian Denomination        4 year degree
# 1                                No Response        4 year degree
# 2                                No Response  Professional degree
# 3                                No Response         Some college
# 4                                No Response         Some college
#
#                   Q8           Q9               Q10  ... Q3_Male  \
# ...

# %%
df.to_csv(output_file, index=False)
